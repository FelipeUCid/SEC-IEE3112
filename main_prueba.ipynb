# %%
import requests
import pandas as pd

class Extractor_Reclamo:
    def __init__(self):
        self.url_api = "https://sec.custhelp.com/services/rest/connect/v1.3/analyticsReportResults"
        self.user = "ProyectoUC"
        self.password = "erMT0eA9QMVRCCle0Im1"

    def get_reclamo(self, id_reporte, paso=10000):
        try:
            offset = 0
            datos_acumulados = []
            columnas = []

            while True:
                body = {
                    "id": id_reporte,
                    "offset": offset
                }
                headers = {
                    "Content-Type": "application/json",
                    "OSvC-CREST-Application-Context": "Run report"
                }
                response = requests.post(
                    self.url_api, 
                    auth=(self.user, self.password),
                    headers=headers,
                    json=body
                )
                if response.status_code != 200:
                    raise ValueError(f"Error en la solicitud: {response.status_code} - {response.text}")
                
                content = response.json()
                filas = content.get("rows", [])
                
                if not filas:
                    break
                if not columnas:
                    columnas = content.get("columnNames", [])
                
                datos_acumulados.extend(filas)
                offset += paso

            return pd.DataFrame(datos_acumulados, columns=columnas)
            
        except Exception as e:
            print(f"Error al procesar el reporte: {e}")
            return None

# Instanciación y uso:
extractor = Extractor_Reclamo()
df_reclamos = extractor.get_reclamo()

# Ahora df_reclamos contendrá la tabla limpia con los valores reales
if df_reclamos is not None:
    print(f"Reporte extraído con éxito. Total de filas: {len(df_reclamos)}")
    print(df_reclamos.head())
# Out:
# Reporte extraído con éxito. Total de filas: 10302
#   ID de incidente  Nº referencia Fecha creada  \
# 0         2159219  240403-000315   03-04-2024
# 1         2166890  240417-000205   17-04-2024
# 2         2177388  240505-000085   05-05-2024
# 3         2178514  240507-000312   07-05-2024
# 4         2181297  240508-000844   08-05-2024
#
#                                  Estado  \
# 0  Confección de propuesta de respuesta
# 1  Confección de propuesta de respuesta
# 2  Confección de propuesta de respuesta
# 3  Confección de propuesta de respuesta
# 4  Confección de propuesta de respuesta
#
#                        Nivel de categoría 3  \
# 0                                     Otros
# 1                             Instalaciones
# 2  Interrupción no programada de suministro
# 3          Problemas de cobro o facturación
# 4          Problemas de cobro o facturación
#
#                    Nivel de categoría 4                       Empresa  \
# 0                                   NaN                           CGE
# 1                                   NaN                           CGE
# 2                     Cortes reiterados                       COPELEC
# 3                      Error de Lectura                           CGE
# 4  Posible cambio en hábitos de consumo  ENEL DISTRIBUCIÓN CHILE S.A.
#
#                                    Petición Concreta  \
# 0  Reposicion de energia antena celular Claro. se...
# 1  1.- Saber como se resuelve el caso, de lo cont...
# 2  Es inestable la luz en esta villa hay cortes d...
# 3  Cobros excesivos Existen sospechas de mala fac...
# 4  Solicita refacturación de montos excesivos por...
#
#                                                Texto  \
# 0  Reposicion de energia antena celular Claro. se...
# 1  Srs SEC. Con mucho sacrificio economico instal...
# 2  Es inestable la luz en esta villa hay cortes d...
# 3  Cobros excesivos \nExisten sospechas de mala f...
# 4  Solicita refacturación de montos excesivos por...
#
#                           Repuesta de Empresa (1era)
# 0  Se da respuesta a organismo, se adjunta carta ...
# 1                                                NaN
# 2  Estimados Señores:\r\nJunto con saludar, adjun...
# 3             Se responde con DGR-SS N 14213518/2024
# 4                                          respuesta
